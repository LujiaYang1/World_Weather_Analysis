# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-90.000, high=90.000, size=2000)
lats_lngs=zip(lats,lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 764

# %%
import requests

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=e7c0244bee4b572924301a59a78a0a61

# %%
from datetime import datetime

# %%
city_data=[]
print("Beginning Data Retrieval")
print("------------------------")

record_count=1
set_count=1

for i, city in enumerate(cities):
    if (i % 50 ==0 and i >= 50):
        set_count+=1
        record_count=1
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count+=1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_des})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | aleppo
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | pangody
# Processing Record 4 of Set 1 | iquique
# Processing Record 5 of Set 1 | presidente medici
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | sistranda
# Processing Record 10 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 1 | kargasok
# Processing Record 13 of Set 1 | seinajoki
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 1 | beloha
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 1 | ushtobe
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | torbay
# Processing Record 25 of Set 1 | abha
# Processing Record 26 of Set 1 | asyut
# Processing Record 27 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 1 | qasigiannguit
# Processing Record 29 of Set 1 | mirzapur
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | rodrigues alves
# Processing Record 36 of Set 1 | mollendo
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | jamame
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | mamallapuram
# Processing Record 41 of Set 1 | sikonge
# Processing Record 42 of Set 1 | douentza
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | ugoofaaru
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | douglas
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | muros
# Processing Record 4 of Set 2 | saint george
# Processing Record 5 of Set 2 | merritt island
# Processing Record 6 of Set 2 | caiaponia
# Processing Record 7 of Set 2 | itarema
# Processing Record 8 of Set 2 | oranjemund
# Processing Record 9 of Set 2 | porto velho
# Processing Record 10 of Set 2 | georgiyevka
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | clyde river
# Processing Record 14 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 2 | dingle
# Processing Record 17 of Set 2 | geraldton
# Processing Record 18 of Set 2 | leh
# Processing Record 19 of Set 2 | nantucket
# Processing Record 20 of Set 2 | dhidhdhoo
# Processing Record 21 of Set 2 | nkhotakota
# Processing Record 22 of Set 2 | guajara-mirim
# City not found. Skipping...
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | blagoyevo
# Processing Record 25 of Set 2 | paulo ramos
# Processing Record 26 of Set 2 | kovdor
# Processing Record 27 of Set 2 | zhezkazgan
# Processing Record 28 of Set 2 | cayenne
# Processing Record 29 of Set 2 | volot
# Processing Record 30 of Set 2 | chililabombwe
# Processing Record 31 of Set 2 | mehamn
# Processing Record 32 of Set 2 | arona
# Processing Record 33 of Set 2 | aswan
# Processing Record 34 of Set 2 | panaba
# Processing Record 35 of Set 2 | laguna
# Processing Record 36 of Set 2 | yarada
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | sarab
# Processing Record 39 of Set 2 | opuwo
# Processing Record 40 of Set 2 | jalu
# Processing Record 41 of Set 2 | ampanihy
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | abatskoye
# Processing Record 44 of Set 2 | eenhana
# Processing Record 45 of Set 2 | kashi
# Processing Record 46 of Set 2 | george town
# Processing Record 47 of Set 2 | honningsvag
# Processing Record 48 of Set 2 | lgov
# Processing Record 49 of Set 2 | mattru
# Processing Record 50 of Set 2 | banposh
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | manono
# Processing Record 4 of Set 3 | sao joao do paraiso
# Processing Record 5 of Set 3 | axim
# Processing Record 6 of Set 3 | ardakan
# Processing Record 7 of Set 3 | sept-iles
# Processing Record 8 of Set 3 | sao geraldo do araguaia
# Processing Record 9 of Set 3 | boa vista
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | arlit
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | narsaq
# Processing Record 14 of Set 3 | yithion
# City not found. Skipping...
# Processing Record 15 of Set 3 | energetik
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | balkanabat
# Processing Record 18 of Set 3 | horki
# Processing Record 19 of Set 3 | olafsvik
# Processing Record 20 of Set 3 | sao jose da coroa grande
# Processing Record 21 of Set 3 | tutoia
# Processing Record 22 of Set 3 | aksu
# Processing Record 23 of Set 3 | viedma
# Processing Record 24 of Set 3 | carrboro
# Processing Record 25 of Set 3 | okemos
# Processing Record 26 of Set 3 | de aar
# Processing Record 27 of Set 3 | mangrol
# Processing Record 28 of Set 3 | leticia
# Processing Record 29 of Set 3 | ilinge
# Processing Record 30 of Set 3 | pangnirtung
# Processing Record 31 of Set 3 | eluru
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | kavaratti
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | port blair
# Processing Record 36 of Set 3 | oktyabrskoye
# Processing Record 37 of Set 3 | taywarah
# Processing Record 38 of Set 3 | brunswick
# Processing Record 39 of Set 3 | vilhena
# Processing Record 40 of Set 3 | normandin
# Processing Record 41 of Set 3 | bagula
# Processing Record 42 of Set 3 | plettenberg bay
# Processing Record 43 of Set 3 | huarmey
# Processing Record 44 of Set 3 | nanortalik
# Processing Record 45 of Set 3 | tingi
# Processing Record 46 of Set 3 | issenye
# Processing Record 47 of Set 3 | loja
# Processing Record 48 of Set 3 | caravelas
# Processing Record 49 of Set 3 | nikolsk
# Processing Record 50 of Set 3 | gwadar
# Processing Record 1 of Set 4 | arambagh
# Processing Record 2 of Set 4 | coquimbo
# Processing Record 3 of Set 4 | othonoi
# City not found. Skipping...
# Processing Record 4 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 4 | villarrobledo
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 4 | la primavera
# Processing Record 9 of Set 4 | fort-shevchenko
# Processing Record 10 of Set 4 | harper
# Processing Record 11 of Set 4 | durusu
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | bandarbeyla
# Processing Record 14 of Set 4 | linhares
# Processing Record 15 of Set 4 | bambous virieux
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | sinnamary
# Processing Record 20 of Set 4 | vardo
# Processing Record 21 of Set 4 | shatki
# Processing Record 22 of Set 4 | tabuk
# Processing Record 23 of Set 4 | chissamba
# Processing Record 24 of Set 4 | adamas
# Processing Record 25 of Set 4 | paris
# Processing Record 26 of Set 4 | jibuti
# Processing Record 27 of Set 4 | mbekenyera
# Processing Record 28 of Set 4 | kangaatsiaq
# Processing Record 29 of Set 4 | wamba
# Processing Record 30 of Set 4 | bowmore
# Processing Record 31 of Set 4 | mullovka
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | kosh-agach
# Processing Record 34 of Set 4 | adeje
# Processing Record 35 of Set 4 | faya
# Processing Record 36 of Set 4 | kushmurun
# Processing Record 37 of Set 4 | jawhar
# Processing Record 38 of Set 4 | dudinka
# Processing Record 39 of Set 4 | paita
# Processing Record 40 of Set 4 | pimenta bueno
# Processing Record 41 of Set 4 | aripuana
# Processing Record 42 of Set 4 | hamilton
# Processing Record 43 of Set 4 | camacha
# Processing Record 44 of Set 4 | puerto ayacucho
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | veraval
# Processing Record 47 of Set 4 | sharan
# Processing Record 48 of Set 4 | oshkosh
# Processing Record 49 of Set 4 | kirgiz-miyaki
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | matara
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | praia da vitoria
# Processing Record 4 of Set 5 | lokosovo
# Processing Record 5 of Set 5 | turukhansk
# Processing Record 6 of Set 5 | cabedelo
# Processing Record 7 of Set 5 | comodoro rivadavia
# Processing Record 8 of Set 5 | igrim
# Processing Record 9 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 5 | padang
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | kharp
# Processing Record 13 of Set 5 | quatre cocos
# Processing Record 14 of Set 5 | najran
# Processing Record 15 of Set 5 | jacareacanga
# Processing Record 16 of Set 5 | las tunas
# Processing Record 17 of Set 5 | loncoche
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | marinette
# Processing Record 20 of Set 5 | bonavista
# Processing Record 21 of Set 5 | adrar
# Processing Record 22 of Set 5 | menongue
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | karasburg
# Processing Record 25 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 26 of Set 5 | eregli
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | gazli
# Processing Record 29 of Set 5 | pundri
# Processing Record 30 of Set 5 | kargil
# Processing Record 31 of Set 5 | oksfjord
# Processing Record 32 of Set 5 | partur
# Processing Record 33 of Set 5 | ginda
# Processing Record 34 of Set 5 | guanica
# Processing Record 35 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 36 of Set 5 | cazaje
# City not found. Skipping...
# Processing Record 37 of Set 5 | sorland
# Processing Record 38 of Set 5 | rognan
# Processing Record 39 of Set 5 | bezenchuk
# Processing Record 40 of Set 5 | florianopolis
# Processing Record 41 of Set 5 | saurimo
# Processing Record 42 of Set 5 | a
# City not found. Skipping...
# Processing Record 43 of Set 5 | neuquen
# Processing Record 44 of Set 5 | yanam
# Processing Record 45 of Set 5 | lyubytino
# Processing Record 46 of Set 5 | barra do garcas
# Processing Record 47 of Set 5 | ambilobe
# Processing Record 48 of Set 5 | morondava
# Processing Record 49 of Set 5 | ayorou
# Processing Record 50 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | korce
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | gimbi
# Processing Record 4 of Set 6 | makrana
# Processing Record 5 of Set 6 | sudbury
# Processing Record 6 of Set 6 | dire
# Processing Record 7 of Set 6 | karla
# Processing Record 8 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 6 | salinas
# Processing Record 10 of Set 6 | agapovka
# Processing Record 11 of Set 6 | aylesbury
# Processing Record 12 of Set 6 | mtambile
# Processing Record 13 of Set 6 | lovozero
# Processing Record 14 of Set 6 | campina verde
# Processing Record 15 of Set 6 | murgab
# Processing Record 16 of Set 6 | marsh harbour
# Processing Record 17 of Set 6 | saint stephen
# Processing Record 18 of Set 6 | frutigen
# Processing Record 19 of Set 6 | tasiilaq
# Processing Record 20 of Set 6 | vrakhation
# Processing Record 21 of Set 6 | timbiqui
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | hajnowka
# Processing Record 24 of Set 6 | havoysund
# Processing Record 25 of Set 6 | ambovombe
# Processing Record 26 of Set 6 | pafos
# Processing Record 27 of Set 6 | khandbari
# Processing Record 28 of Set 6 | weligama
# Processing Record 29 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 6 | kochevo
# Processing Record 31 of Set 6 | roatan
# Processing Record 32 of Set 6 | kardla
# Processing Record 33 of Set 6 | kemijarvi
# Processing Record 34 of Set 6 | maraa
# Processing Record 35 of Set 6 | rock sound
# Processing Record 36 of Set 6 | ponta delgada
# Processing Record 37 of Set 6 | cravo norte
# Processing Record 38 of Set 6 | los amates
# Processing Record 39 of Set 6 | jorochito
# Processing Record 40 of Set 6 | puerto padre
# Processing Record 41 of Set 6 | castro
# Processing Record 42 of Set 6 | havelock
# Processing Record 43 of Set 6 | punta cardon
# Processing Record 44 of Set 6 | natal
# Processing Record 45 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 6 | farmington
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | la asuncion
# Processing Record 49 of Set 6 | burayevo
# Processing Record 50 of Set 6 | sal rei
# Processing Record 1 of Set 7 | tombouctou
# Processing Record 2 of Set 7 | oswego
# Processing Record 3 of Set 7 | kapuskasing
# Processing Record 4 of Set 7 | kutum
# Processing Record 5 of Set 7 | almeirim
# Processing Record 6 of Set 7 | mocuba
# Processing Record 7 of Set 7 | achit
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | nanga eboko
# Processing Record 10 of Set 7 | ballina
# Processing Record 11 of Set 7 | kabare
# Processing Record 12 of Set 7 | mwinilunga
# Processing Record 13 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 14 of Set 7 | parabel
# Processing Record 15 of Set 7 | mortka
# Processing Record 16 of Set 7 | bodden town
# Processing Record 17 of Set 7 | leshukonskoye
# Processing Record 18 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 19 of Set 7 | kalmunai
# Processing Record 20 of Set 7 | mpulungu
# Processing Record 21 of Set 7 | chipinge
# Processing Record 22 of Set 7 | talnakh
# Processing Record 23 of Set 7 | dukhovnitskoye
# Processing Record 24 of Set 7 | mayor pablo lagerenza
# Processing Record 25 of Set 7 | daoukro
# Processing Record 26 of Set 7 | aden
# Processing Record 27 of Set 7 | manoel urbano
# Processing Record 28 of Set 7 | marienburg
# Processing Record 29 of Set 7 | bobrovka
# Processing Record 30 of Set 7 | palani
# Processing Record 31 of Set 7 | volnoye
# Processing Record 32 of Set 7 | adilabad
# Processing Record 33 of Set 7 | areosa
# Processing Record 34 of Set 7 | shihezi
# Processing Record 35 of Set 7 | kayerkan
# Processing Record 36 of Set 7 | aguadilla
# Processing Record 37 of Set 7 | evanston
# Processing Record 38 of Set 7 | senanga
# Processing Record 39 of Set 7 | boende
# Processing Record 40 of Set 7 | otavi
# Processing Record 41 of Set 7 | itaituba
# Processing Record 42 of Set 7 | sechura
# Processing Record 43 of Set 7 | calabar
# Processing Record 44 of Set 7 | nawa
# Processing Record 45 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 7 | letlhakeng
# Processing Record 47 of Set 7 | puerto ayora
# Processing Record 48 of Set 7 | chuy
# Processing Record 49 of Set 7 | gweta
# Processing Record 50 of Set 7 | fandriana
# Processing Record 1 of Set 8 | presidente prudente
# Processing Record 2 of Set 8 | maragogi
# Processing Record 3 of Set 8 | mbanza-ngungu
# Processing Record 4 of Set 8 | bobo dioulasso
# Processing Record 5 of Set 8 | vaasa
# Processing Record 6 of Set 8 | san julian
# Processing Record 7 of Set 8 | jarva-jaani
# Processing Record 8 of Set 8 | ribeira brava
# Processing Record 9 of Set 8 | heiligenhafen
# Processing Record 10 of Set 8 | santa catalina
# Processing Record 11 of Set 8 | nauta
# Processing Record 12 of Set 8 | vagay
# Processing Record 13 of Set 8 | carauari
# Processing Record 14 of Set 8 | ernei
# Processing Record 15 of Set 8 | namibe
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | rafai
# Processing Record 18 of Set 8 | parry sound
# Processing Record 19 of Set 8 | lukulu
# Processing Record 20 of Set 8 | albany
# Processing Record 21 of Set 8 | kyshtovka
# Processing Record 22 of Set 8 | tazovskiy
# Processing Record 23 of Set 8 | ovalle
# Processing Record 24 of Set 8 | ovre ardal
# Processing Record 25 of Set 8 | capreol
# Processing Record 26 of Set 8 | miguel calmon
# Processing Record 27 of Set 8 | codrington
# Processing Record 28 of Set 8 | carnarvon
# Processing Record 29 of Set 8 | san diego de los banos
# Processing Record 30 of Set 8 | burica
# City not found. Skipping...
# Processing Record 31 of Set 8 | disna
# Processing Record 32 of Set 8 | maurepas
# Processing Record 33 of Set 8 | tessalit
# Processing Record 34 of Set 8 | vila franca do campo
# Processing Record 35 of Set 8 | birao
# Processing Record 36 of Set 8 | kattivakkam
# Processing Record 37 of Set 8 | carutapera
# Processing Record 38 of Set 8 | ystad
# Processing Record 39 of Set 8 | gasa
# Processing Record 40 of Set 8 | pandharpur
# Processing Record 41 of Set 8 | issoudun
# Processing Record 42 of Set 8 | bueno brandao
# Processing Record 43 of Set 8 | biedenkopf
# Processing Record 44 of Set 8 | amapa
# Processing Record 45 of Set 8 | mezen
# Processing Record 46 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 48 of Set 8 | sakakah
# Processing Record 49 of Set 8 | husavik
# Processing Record 50 of Set 8 | adre
# Processing Record 1 of Set 9 | valdivia
# Processing Record 2 of Set 9 | karpogory
# Processing Record 3 of Set 9 | penzance
# Processing Record 4 of Set 9 | mandera
# Processing Record 5 of Set 9 | klaebu
# Processing Record 6 of Set 9 | waddan
# Processing Record 7 of Set 9 | la rioja
# Processing Record 8 of Set 9 | praia
# Processing Record 9 of Set 9 | nikki
# Processing Record 10 of Set 9 | birjand
# Processing Record 11 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 9 | sovetskiy
# Processing Record 13 of Set 9 | kuzino
# Processing Record 14 of Set 9 | rehoboth
# Processing Record 15 of Set 9 | jaciara
# Processing Record 16 of Set 9 | garwolin
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | margate
# Processing Record 19 of Set 9 | inhambane
# Processing Record 20 of Set 9 | nalut
# Processing Record 21 of Set 9 | hofn
# Processing Record 22 of Set 9 | grindavik
# Processing Record 23 of Set 9 | sanary-sur-mer
# Processing Record 24 of Set 9 | bokovskaya
# Processing Record 25 of Set 9 | agua branca
# Processing Record 26 of Set 9 | burla
# Processing Record 27 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 28 of Set 9 | maceio
# Processing Record 29 of Set 9 | nova olimpia
# Processing Record 30 of Set 9 | sambava
# Processing Record 31 of Set 9 | melito di porto salvo
# Processing Record 32 of Set 9 | gander
# Processing Record 33 of Set 9 | salalah
# Processing Record 34 of Set 9 | moose factory
# Processing Record 35 of Set 9 | benghazi
# Processing Record 36 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint-pierre
# Processing Record 38 of Set 9 | quime
# Processing Record 39 of Set 9 | ejura
# Processing Record 40 of Set 9 | ngaoundere
# Processing Record 41 of Set 9 | galle
# Processing Record 42 of Set 9 | havre-saint-pierre
# Processing Record 43 of Set 9 | sao joao da barra
# Processing Record 44 of Set 9 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 45 of Set 9 | vestmannaeyjar
# Processing Record 46 of Set 9 | kulhudhuffushi
# Processing Record 47 of Set 9 | guider
# Processing Record 48 of Set 9 | teguise
# Processing Record 49 of Set 9 | koulikoro
# Processing Record 50 of Set 9 | santa isabel
# Processing Record 1 of Set 10 | maracacume
# Processing Record 2 of Set 10 | kneza
# City not found. Skipping...
# Processing Record 3 of Set 10 | scarborough
# Processing Record 4 of Set 10 | porciuncula
# Processing Record 5 of Set 10 | sur
# Processing Record 6 of Set 10 | derzhavinsk
# Processing Record 7 of Set 10 | karlskrona
# Processing Record 8 of Set 10 | bembereke
# Processing Record 9 of Set 10 | ramotswa
# Processing Record 10 of Set 10 | sangolqui
# Processing Record 11 of Set 10 | wittmund
# Processing Record 12 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 13 of Set 10 | tshane
# Processing Record 14 of Set 10 | kasane
# Processing Record 15 of Set 10 | richards bay
# Processing Record 16 of Set 10 | walvis bay
# Processing Record 17 of Set 10 | meulaboh
# Processing Record 18 of Set 10 | liverpool
# Processing Record 19 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 20 of Set 10 | fomboni
# Processing Record 21 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 10 | saint anthony
# Processing Record 23 of Set 10 | dwarka
# Processing Record 24 of Set 10 | santa cruz cabralia
# Processing Record 25 of Set 10 | imbituba
# Processing Record 26 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 27 of Set 10 | aurdal
# Processing Record 28 of Set 10 | south patrick shores
# Processing Record 29 of Set 10 | micheweni
# Processing Record 30 of Set 10 | kodinar
# Processing Record 31 of Set 10 | cap malheureux
# Processing Record 32 of Set 10 | parana
# Processing Record 33 of Set 10 | paragominas
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | makat
# Processing Record 36 of Set 10 | kisangani
# Processing Record 37 of Set 10 | greytown
# Processing Record 38 of Set 10 | san borja
# Processing Record 39 of Set 10 | lodja
# Processing Record 40 of Set 10 | san andres
# Processing Record 41 of Set 10 | maarianhamina
# Processing Record 42 of Set 10 | bilma
# Processing Record 43 of Set 10 | fonte boa
# Processing Record 44 of Set 10 | maniwaki
# Processing Record 45 of Set 10 | kisujszallas
# Processing Record 46 of Set 10 | campobello di mazara
# Processing Record 47 of Set 10 | ust-tsilma
# Processing Record 48 of Set 10 | belle glade
# Processing Record 49 of Set 10 | parksepa
# Processing Record 50 of Set 10 | manzil kamil
# Processing Record 1 of Set 11 | toledo
# Processing Record 2 of Set 11 | krasnoye
# Processing Record 3 of Set 11 | filingue
# Processing Record 4 of Set 11 | lusaka
# Processing Record 5 of Set 11 | adwa
# Processing Record 6 of Set 11 | chiredzi
# Processing Record 7 of Set 11 | nuuk
# Processing Record 8 of Set 11 | trelew
# Processing Record 9 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 11 | albanel
# Processing Record 11 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 11 | nizhniy baskunchak
# Processing Record 13 of Set 11 | opochka
# Processing Record 14 of Set 11 | los llanos de aridane
# Processing Record 15 of Set 11 | vila velha
# Processing Record 16 of Set 11 | carmen del parana
# Processing Record 17 of Set 11 | roros
# Processing Record 18 of Set 11 | pozo colorado
# Processing Record 19 of Set 11 | santa cruz de tenerife
# Processing Record 20 of Set 11 | qaqortoq
# Processing Record 21 of Set 11 | elizabeth city
# Processing Record 22 of Set 11 | kousseri
# Processing Record 23 of Set 11 | bereda
# Processing Record 24 of Set 11 | millinocket
# Processing Record 25 of Set 11 | vaxjo
# Processing Record 26 of Set 11 | kasempa
# Processing Record 27 of Set 11 | maniitsoq
# Processing Record 28 of Set 11 | japura
# Processing Record 29 of Set 11 | kursenai
# Processing Record 30 of Set 11 | santa cruz
# Processing Record 31 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 11 | rocha
# Processing Record 33 of Set 11 | hickory
# Processing Record 34 of Set 11 | mineros
# Processing Record 35 of Set 11 | chicama
# Processing Record 36 of Set 11 | balezino
# Processing Record 37 of Set 11 | laguna de perlas
# Processing Record 38 of Set 11 | santa maria
# Processing Record 39 of Set 11 | perelyub
# Processing Record 40 of Set 11 | pisco
# Processing Record 41 of Set 11 | sirohi
# Processing Record 42 of Set 11 | rudsar
# Processing Record 43 of Set 11 | kindu
# Processing Record 44 of Set 11 | punta umbria
# Processing Record 45 of Set 11 | thinadhoo
# Processing Record 46 of Set 11 | lubben
# Processing Record 47 of Set 11 | puerto suarez
# Processing Record 48 of Set 11 | bhitarwar
# Processing Record 49 of Set 11 | kaka
# Processing Record 50 of Set 11 | baraki barak
# Processing Record 1 of Set 12 | spring hill
# Processing Record 2 of Set 12 | severnoye
# Processing Record 3 of Set 12 | bodo
# Processing Record 4 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 12 | kita
# Processing Record 6 of Set 12 | taoudenni
# Processing Record 7 of Set 12 | libreville
# Processing Record 8 of Set 12 | ciudad bolivar
# Processing Record 9 of Set 12 | gamba
# Processing Record 10 of Set 12 | saint-francois
# Processing Record 11 of Set 12 | opelika
# Processing Record 12 of Set 12 | uzumlu
# City not found. Skipping...
# Processing Record 13 of Set 12 | le mans
# Processing Record 14 of Set 12 | amravati
# Processing Record 15 of Set 12 | glen allen
# Processing Record 16 of Set 12 | omboue
# Processing Record 17 of Set 12 | puerto carreno
# Processing Record 18 of Set 12 | ajdabiya
# Processing Record 19 of Set 12 | hurghada
# Processing Record 20 of Set 12 | funadhoo
# Processing Record 21 of Set 12 | presidente epitacio
# Processing Record 22 of Set 12 | brae
# Processing Record 23 of Set 12 | entre rios
# Processing Record 24 of Set 12 | allapalli
# Processing Record 25 of Set 12 | talcahuano
# Processing Record 26 of Set 12 | olenino
# Processing Record 27 of Set 12 | beyla
# Processing Record 28 of Set 12 | vondrozo
# Processing Record 29 of Set 12 | guarapari
# Processing Record 30 of Set 12 | marsa matruh
# Processing Record 31 of Set 12 | agadez
# Processing Record 32 of Set 12 | woodlyn
# Processing Record 33 of Set 12 | pianoro
# Processing Record 34 of Set 12 | asti
# Processing Record 35 of Set 12 | yubileynyy
# Processing Record 36 of Set 12 | noyabrsk
# Processing Record 37 of Set 12 | stykkisholmur
# Processing Record 38 of Set 12 | doha
# Processing Record 39 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 40 of Set 12 | bull savanna
# Processing Record 41 of Set 12 | mitsamiouli
# Processing Record 42 of Set 12 | mana
# Processing Record 43 of Set 12 | kondoa
# Processing Record 44 of Set 12 | salinopolis
# Processing Record 45 of Set 12 | oyem
# Processing Record 46 of Set 12 | andenes
# Processing Record 47 of Set 12 | puerto leguizamo
# Processing Record 48 of Set 12 | korla
# Processing Record 49 of Set 12 | kastamonu
# Processing Record 50 of Set 12 | allada
# Processing Record 1 of Set 13 | khalandritsa
# City not found. Skipping...
# Processing Record 2 of Set 13 | saryozek
# Processing Record 3 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 4 of Set 13 | afua
# Processing Record 5 of Set 13 | boda
# Processing Record 6 of Set 13 | nkowakowa
# Processing Record 7 of Set 13 | reconquista
# Processing Record 8 of Set 13 | port-cartier
# Processing Record 9 of Set 13 | selma
# Processing Record 10 of Set 13 | lincoln
# Processing Record 11 of Set 13 | bonthe
# Processing Record 12 of Set 13 | taltal
# Processing Record 13 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 13 | paamiut
# Processing Record 15 of Set 13 | west bay
# Processing Record 16 of Set 13 | solano
# Processing Record 17 of Set 13 | warrington
# Processing Record 18 of Set 13 | brusque
# Processing Record 19 of Set 13 | brahmapuri
# City not found. Skipping...
# Processing Record 20 of Set 13 | asosa
# Processing Record 21 of Set 13 | shiraz
# Processing Record 22 of Set 13 | karachi
# Processing Record 23 of Set 13 | sarh
# Processing Record 24 of Set 13 | karasjok
# Processing Record 25 of Set 13 | khorixas
# Processing Record 26 of Set 13 | junin
# Processing Record 27 of Set 13 | isla mujeres
# Processing Record 28 of Set 13 | tashtyp
# Processing Record 29 of Set 13 | jamsa
# Processing Record 30 of Set 13 | ladario
# Processing Record 31 of Set 13 | itupiranga
# Processing Record 32 of Set 13 | san javier
# Processing Record 33 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 34 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 35 of Set 13 | dakar
# Processing Record 36 of Set 13 | montepuez
# Processing Record 37 of Set 13 | shinpokh
# Processing Record 38 of Set 13 | kericho
# Processing Record 39 of Set 13 | cotonou
# Processing Record 40 of Set 13 | villa rica
# Processing Record 41 of Set 13 | megion
# Processing Record 42 of Set 13 | shelburne
# Processing Record 43 of Set 13 | borovichi
# Processing Record 44 of Set 13 | hit
# Processing Record 45 of Set 13 | salamiyah
# Processing Record 46 of Set 13 | mahon
# Processing Record 47 of Set 13 | soyo
# Processing Record 48 of Set 13 | emba
# Processing Record 49 of Set 13 | crixas
# Processing Record 50 of Set 13 | cassilandia
# Processing Record 1 of Set 14 | turkistan
# Processing Record 2 of Set 14 | shetpe
# Processing Record 3 of Set 14 | great yarmouth
# Processing Record 4 of Set 14 | olinda
# Processing Record 5 of Set 14 | bonfim
# Processing Record 6 of Set 14 | raudeberg
# Processing Record 7 of Set 14 | keuruu
# Processing Record 8 of Set 14 | biograd na moru
# Processing Record 9 of Set 14 | saint-joseph
# Processing Record 10 of Set 14 | svetlyy
# Processing Record 11 of Set 14 | clarence town
# Processing Record 12 of Set 14 | thabazimbi
# Processing Record 13 of Set 14 | suez
# Processing Record 14 of Set 14 | buraydah
# Processing Record 15 of Set 14 | prainha
# Processing Record 16 of Set 14 | muhos
# Processing Record 17 of Set 14 | macon
# Processing Record 18 of Set 14 | biscarrosse
# Processing Record 19 of Set 14 | loviisa
# Processing Record 20 of Set 14 | naryan-mar
# Processing Record 21 of Set 14 | siuna
# Processing Record 22 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 23 of Set 14 | eirunepe
# Processing Record 24 of Set 14 | gouyave
# Processing Record 25 of Set 14 | wampusirpi
# City not found. Skipping...
# Processing Record 26 of Set 14 | malkangiri
# Processing Record 27 of Set 14 | abu samrah
# Processing Record 28 of Set 14 | san pedro
# Processing Record 29 of Set 14 | quelimane
# Processing Record 30 of Set 14 | eatonton
# Processing Record 31 of Set 14 | nouadhibou
# Processing Record 32 of Set 14 | martil
# Processing Record 33 of Set 14 | presidencia roque saenz pena
# Processing Record 34 of Set 14 | freeport
# Processing Record 35 of Set 14 | edremit
# Processing Record 36 of Set 14 | miraflores
# Processing Record 37 of Set 14 | makungu
# Processing Record 38 of Set 14 | mecca
# Processing Record 39 of Set 14 | gobabis
# Processing Record 40 of Set 14 | antalaha
# Processing Record 41 of Set 14 | madimba
# Processing Record 42 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 14 | redcliffe
# Processing Record 44 of Set 14 | chaumont
# Processing Record 45 of Set 14 | safaga
# Processing Record 46 of Set 14 | salair
# Processing Record 47 of Set 14 | shahreza
# Processing Record 48 of Set 14 | niquelandia
# Processing Record 49 of Set 14 | alvorada
# Processing Record 50 of Set 14 | rena
# Processing Record 1 of Set 15 | bentiu
# Processing Record 2 of Set 15 | lucea
# Processing Record 3 of Set 15 | alem paraiba
# Processing Record 4 of Set 15 | kharan
# Processing Record 5 of Set 15 | marawi
# Processing Record 6 of Set 15 | nakhabino
# Processing Record 7 of Set 15 | kuopio
# Processing Record 8 of Set 15 | marica
# Processing Record 9 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 15 | chillicothe
# Processing Record 11 of Set 15 | nagua
# Processing Record 12 of Set 15 | saint-ambroise
# Processing Record 13 of Set 15 | azuaga
# Processing Record 14 of Set 15 | cape canaveral
# Processing Record 15 of Set 15 | saint-georges
# Processing Record 16 of Set 15 | chilca
# Processing Record 17 of Set 15 | jacmel
# Processing Record 18 of Set 15 | rio gallegos
# Processing Record 19 of Set 15 | duku
# Processing Record 20 of Set 15 | naron
# Processing Record 21 of Set 15 | erdemli
# Processing Record 22 of Set 15 | kayes
# Processing Record 23 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 15 | awjilah
# Processing Record 25 of Set 15 | pietersburg
# Processing Record 26 of Set 15 | iralaya
# Processing Record 27 of Set 15 | dera ghazi khan
# Processing Record 28 of Set 15 | unai
# Processing Record 29 of Set 15 | perleberg
# Processing Record 30 of Set 15 | henties bay
# Processing Record 31 of Set 15 | les cayes
# Processing Record 32 of Set 15 | gat
# Processing Record 33 of Set 15 | dombas
# Processing Record 34 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 15 | caconda
# Processing Record 36 of Set 15 | grootfontein
# Processing Record 37 of Set 15 | villa carlos paz
# Processing Record 38 of Set 15 | bakchar
# Processing Record 39 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 40 of Set 15 | bud
# Processing Record 41 of Set 15 | berlevag
# Processing Record 42 of Set 15 | tubuala
# Processing Record 43 of Set 15 | ronse
# Processing Record 44 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 15 | shache
# Processing Record 46 of Set 15 | umba
# Processing Record 47 of Set 15 | lasa
# Processing Record 48 of Set 15 | ouadda
# Processing Record 49 of Set 15 | duiwelskloof
# Processing Record 50 of Set 15 | prikubanskiy
# Processing Record 1 of Set 16 | goderich
# Processing Record 2 of Set 16 | syracuse
# Processing Record 3 of Set 16 | tvedestrand
# Processing Record 4 of Set 16 | obukhiv
# Processing Record 5 of Set 16 | poco branco
# Processing Record 6 of Set 16 | odweyne
# Processing Record 7 of Set 16 | riyadh
# Processing Record 8 of Set 16 | ust-kalmanka
# Processing Record 9 of Set 16 | lar
# Processing Record 10 of Set 16 | general pico
# Processing Record 11 of Set 16 | maridi
# Processing Record 12 of Set 16 | gayny
# Processing Record 13 of Set 16 | portalegre
# Processing Record 14 of Set 16 | of
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#                   City Country      Lat      Lng  Max Temp  Humidity  \
# 0               Aleppo      SY  36.2500  37.5000     53.11        75
# 1              Ushuaia      AR -54.8000 -68.3000     44.60        81
# 2              Pangody      RU  65.8500  74.4859     16.30        95
# 3              Iquique      CL -20.2208 -70.1431     78.80        44
# 4    Presidente Medici      BR -11.1753 -61.9014     74.34        96
# ..                 ...     ...      ...      ...       ...       ...
# 695                Lar      IN  26.2039  83.9717     75.00        21
# 696       General Pico      AR -35.6566 -63.7568     81.10        49
# 697             Maridi      SS   4.9158  29.4742     79.39        54
# 698              Gayny      RU  60.3071  54.3241     26.51        94
# 699         Portalegre      PT  39.2938  -7.4312     71.60        35
#
#      Cloudiness  Wind Speed Current Description
# 0            30       13.69    scattered clouds
# 1            40       37.98          light rain
# 2           100        6.76          light snow
# 3             0       16.11           clear sky
# 4           100        2.68     overcast clouds
# ..          ...         ...                 ...
# 695           0        5.99           clear sky
# 696         100       21.03     overcast clouds
# 697          89        2.10          light rain
# 698         100        8.32     overcast clouds
# 699           0        5.75           clear sky
#
# [700 rows x 9 columns]

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file,index_label="City_ID")
