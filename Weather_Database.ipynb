# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-90.000, high=90.000, size=2000)
lats_lngs=zip(lats,lngs)
lats_lngs

# %%
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 750

# %%
import requests

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=e7c0244bee4b572924301a59a78a0a61

# %%
from datetime import datetime

# %%
city_data=[]
print("Beginning Data Retrieval")
print("------------------------")

record_count=1
set_count=1

for i, city in enumerate(cities):
    if (i % 50 ==0 and i >= 50):
        set_count+=1
        record_count=1
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count+=1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_des})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | constitucion
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | lusambo
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | nouadhibou
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | batticaloa
# Processing Record 8 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 1 | camacupa
# Processing Record 10 of Set 1 | vila velha
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | souillac
# Processing Record 13 of Set 1 | capitao poco
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | lagoa
# Processing Record 19 of Set 1 | henties bay
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | nueva florida
# Processing Record 22 of Set 1 | bonavista
# Processing Record 23 of Set 1 | mehamn
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | ntcheu
# Processing Record 26 of Set 1 | gat
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | normandin
# Processing Record 31 of Set 1 | praia
# Processing Record 32 of Set 1 | sambava
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | taloqan
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | raudeberg
# Processing Record 38 of Set 1 | scarborough
# Processing Record 39 of Set 1 | kandi
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | hofn
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | waldshut-tiengen
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | the valley
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | point fortin
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | isla mujeres
# Processing Record 50 of Set 1 | sanandaj
# Processing Record 1 of Set 2 | corinto
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 4 of Set 2 | san cristobal
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | gewane
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | walvis bay
# Processing Record 12 of Set 2 | lawrenceburg
# Processing Record 13 of Set 2 | opuwo
# Processing Record 14 of Set 2 | namibe
# Processing Record 15 of Set 2 | yokadouma
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | tikapur
# Processing Record 18 of Set 2 | saint-joseph
# Processing Record 19 of Set 2 | mindelo
# Processing Record 20 of Set 2 | manawar
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | mongoumba
# Processing Record 24 of Set 2 | calamar
# Processing Record 25 of Set 2 | coihaique
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | santa rosa
# Processing Record 30 of Set 2 | pinhao
# Processing Record 31 of Set 2 | narasannapeta
# Processing Record 32 of Set 2 | nurota
# Processing Record 33 of Set 2 | husavik
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | jutai
# Processing Record 36 of Set 2 | hurghada
# Processing Record 37 of Set 2 | bolshoye murashkino
# Processing Record 38 of Set 2 | mahasamund
# Processing Record 39 of Set 2 | bereda
# Processing Record 40 of Set 2 | suzzara
# Processing Record 41 of Set 2 | serafimovich
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | medina
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | igoumenitsa
# Processing Record 46 of Set 2 | vestmannaeyjar
# Processing Record 47 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | thinadhoo
# Processing Record 50 of Set 2 | matagami
# Processing Record 1 of Set 3 | bubaque
# Processing Record 2 of Set 3 | uribia
# Processing Record 3 of Set 3 | medea
# Processing Record 4 of Set 3 | matara
# Processing Record 5 of Set 3 | leshukonskoye
# Processing Record 6 of Set 3 | trairi
# Processing Record 7 of Set 3 | angoche
# Processing Record 8 of Set 3 | sao filipe
# Processing Record 9 of Set 3 | olafsvik
# Processing Record 10 of Set 3 | wattegama
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | comodoro rivadavia
# Processing Record 13 of Set 3 | shetpe
# Processing Record 14 of Set 3 | beloha
# Processing Record 15 of Set 3 | brae
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | tiznit
# Processing Record 18 of Set 3 | cassilandia
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | rawson
# Processing Record 22 of Set 3 | soyo
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | muros
# Processing Record 25 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 26 of Set 3 | valkeala
# Processing Record 27 of Set 3 | sheregesh
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | ponta delgada
# Processing Record 30 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 3 | arbelaez
# Processing Record 32 of Set 3 | oktyabrskoye
# Processing Record 33 of Set 3 | adrar
# Processing Record 34 of Set 3 | minab
# Processing Record 35 of Set 3 | port shepstone
# Processing Record 36 of Set 3 | ilebo
# Processing Record 37 of Set 3 | libreville
# Processing Record 38 of Set 3 | yverdon
# City not found. Skipping...
# Processing Record 39 of Set 3 | berlevag
# Processing Record 40 of Set 3 | albertville
# Processing Record 41 of Set 3 | wiarton
# Processing Record 42 of Set 3 | puerto cabezas
# Processing Record 43 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 3 | puerto baquerizo moreno
# Processing Record 45 of Set 3 | nantucket
# Processing Record 46 of Set 3 | hanko
# Processing Record 47 of Set 3 | shakawe
# Processing Record 48 of Set 3 | waynesville
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 3 | banda aceh
# Processing Record 1 of Set 4 | lipin bor
# Processing Record 2 of Set 4 | bassila
# Processing Record 3 of Set 4 | judaberg
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | kyenjojo
# Processing Record 6 of Set 4 | mastic beach
# Processing Record 7 of Set 4 | shache
# Processing Record 8 of Set 4 | grindavik
# Processing Record 9 of Set 4 | aswan
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | cape town
# Processing Record 12 of Set 4 | mitsamiouli
# Processing Record 13 of Set 4 | sovetsk
# Processing Record 14 of Set 4 | chamba
# Processing Record 15 of Set 4 | bathsheba
# Processing Record 16 of Set 4 | bondo
# Processing Record 17 of Set 4 | bartica
# Processing Record 18 of Set 4 | harper
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | rocha
# Processing Record 21 of Set 4 | antofagasta
# Processing Record 22 of Set 4 | verkhnyaya toyma
# Processing Record 23 of Set 4 | vardo
# Processing Record 24 of Set 4 | bekwai
# Processing Record 25 of Set 4 | yusva
# City not found. Skipping...
# Processing Record 26 of Set 4 | yar-sale
# Processing Record 27 of Set 4 | balkanabat
# Processing Record 28 of Set 4 | boa vista
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | inhambane
# Processing Record 33 of Set 4 | corn island
# Processing Record 34 of Set 4 | yershichi
# Processing Record 35 of Set 4 | cockburn town
# Processing Record 36 of Set 4 | gravdal
# Processing Record 37 of Set 4 | laguna
# Processing Record 38 of Set 4 | muisne
# Processing Record 39 of Set 4 | kondopoga
# Processing Record 40 of Set 4 | teguise
# Processing Record 41 of Set 4 | murdochville
# Processing Record 42 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 4 | yalta
# Processing Record 44 of Set 4 | trabzon
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | takoradi
# Processing Record 47 of Set 4 | tsogni
# Processing Record 48 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 4 | asyut
# Processing Record 50 of Set 4 | totskoye
# Processing Record 1 of Set 5 | sombrio
# Processing Record 2 of Set 5 | maragogi
# Processing Record 3 of Set 5 | kankon
# Processing Record 4 of Set 5 | tromso
# Processing Record 5 of Set 5 | cruzeiro do oeste
# Processing Record 6 of Set 5 | dondo
# Processing Record 7 of Set 5 | brenes
# Processing Record 8 of Set 5 | sao sebastiao
# Processing Record 9 of Set 5 | yukamenskoye
# Processing Record 10 of Set 5 | camana
# Processing Record 11 of Set 5 | lannion
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | karwar
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | west bay
# Processing Record 16 of Set 5 | synya
# Processing Record 17 of Set 5 | manaus
# Processing Record 18 of Set 5 | hambantota
# Processing Record 19 of Set 5 | wad rawah
# Processing Record 20 of Set 5 | canalete
# Processing Record 21 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | marzuq
# Processing Record 24 of Set 5 | sao joao da barra
# Processing Record 25 of Set 5 | havelock
# Processing Record 26 of Set 5 | faya
# Processing Record 27 of Set 5 | el alto
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | zambezi
# Processing Record 30 of Set 5 | barra do bugres
# Processing Record 31 of Set 5 | carutapera
# Processing Record 32 of Set 5 | onega
# Processing Record 33 of Set 5 | kruisfontein
# Processing Record 34 of Set 5 | andilamena
# Processing Record 35 of Set 5 | qaanaaq
# Processing Record 36 of Set 5 | kalmunai
# Processing Record 37 of Set 5 | changji
# Processing Record 38 of Set 5 | tambura
# Processing Record 39 of Set 5 | carauari
# Processing Record 40 of Set 5 | eura
# Processing Record 41 of Set 5 | idanre
# Processing Record 42 of Set 5 | chimbote
# Processing Record 43 of Set 5 | borovoy
# Processing Record 44 of Set 5 | atyuryevo
# City not found. Skipping...
# Processing Record 45 of Set 5 | mangawan
# Processing Record 46 of Set 5 | khorixas
# Processing Record 47 of Set 5 | bardsir
# Processing Record 48 of Set 5 | rincon
# Processing Record 49 of Set 5 | nuuk
# Processing Record 50 of Set 5 | vallenar
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | umm kaddadah
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | dire dawa
# Processing Record 5 of Set 6 | ibimirim
# Processing Record 6 of Set 6 | awbari
# Processing Record 7 of Set 6 | sao cristovao
# Processing Record 8 of Set 6 | moengo
# Processing Record 9 of Set 6 | gasa
# Processing Record 10 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 6 | atasu
# Processing Record 12 of Set 6 | vestmanna
# Processing Record 13 of Set 6 | krasnoselkup
# Processing Record 14 of Set 6 | skelleftea
# Processing Record 15 of Set 6 | kautokeino
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | port said
# Processing Record 19 of Set 6 | senanga
# Processing Record 20 of Set 6 | goba
# Processing Record 21 of Set 6 | tarbes
# Processing Record 22 of Set 6 | kholmogory
# Processing Record 23 of Set 6 | drymen
# Processing Record 24 of Set 6 | ornskoldsvik
# Processing Record 25 of Set 6 | chandbali
# Processing Record 26 of Set 6 | grand-lahou
# Processing Record 27 of Set 6 | llanes
# Processing Record 28 of Set 6 | ailigandi
# Processing Record 29 of Set 6 | beni mazar
# Processing Record 30 of Set 6 | zabol
# Processing Record 31 of Set 6 | omaruru
# Processing Record 32 of Set 6 | surt
# Processing Record 33 of Set 6 | watsa
# Processing Record 34 of Set 6 | janakkala
# Processing Record 35 of Set 6 | japura
# Processing Record 36 of Set 6 | tambacounda
# Processing Record 37 of Set 6 | najran
# Processing Record 38 of Set 6 | samfya
# Processing Record 39 of Set 6 | lithakia
# Processing Record 40 of Set 6 | nalut
# Processing Record 41 of Set 6 | piterka
# Processing Record 42 of Set 6 | vitry-le-francois
# Processing Record 43 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 6 | ambanja
# Processing Record 45 of Set 6 | puebloviejo
# Processing Record 46 of Set 6 | maniitsoq
# Processing Record 47 of Set 6 | ariquemes
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | manaure
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | tselinnoye
# Processing Record 2 of Set 7 | luau
# Processing Record 3 of Set 7 | llangefni
# Processing Record 4 of Set 7 | chapais
# Processing Record 5 of Set 7 | exeter
# Processing Record 6 of Set 7 | talcahuano
# Processing Record 7 of Set 7 | chicama
# Processing Record 8 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 7 | nortelandia
# Processing Record 10 of Set 7 | hamilton
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | shakhty
# Processing Record 13 of Set 7 | gornopravdinsk
# Processing Record 14 of Set 7 | bandarbeyla
# Processing Record 15 of Set 7 | jardim
# Processing Record 16 of Set 7 | abapo
# Processing Record 17 of Set 7 | owando
# Processing Record 18 of Set 7 | jalingo
# Processing Record 19 of Set 7 | sur
# Processing Record 20 of Set 7 | cancun
# Processing Record 21 of Set 7 | tonshayevo
# Processing Record 22 of Set 7 | orgun
# City not found. Skipping...
# Processing Record 23 of Set 7 | zavallya
# Processing Record 24 of Set 7 | goderich
# Processing Record 25 of Set 7 | sisimiut
# Processing Record 26 of Set 7 | plettenberg bay
# Processing Record 27 of Set 7 | necochea
# Processing Record 28 of Set 7 | talnakh
# Processing Record 29 of Set 7 | palmares do sul
# Processing Record 30 of Set 7 | barberton
# Processing Record 31 of Set 7 | azovo
# Processing Record 32 of Set 7 | elizabeth city
# Processing Record 33 of Set 7 | fez
# Processing Record 34 of Set 7 | madisonville
# Processing Record 35 of Set 7 | snezhnogorsk
# Processing Record 36 of Set 7 | sept-iles
# Processing Record 37 of Set 7 | luanda
# Processing Record 38 of Set 7 | puerto lempira
# Processing Record 39 of Set 7 | mecca
# Processing Record 40 of Set 7 | lyubim
# Processing Record 41 of Set 7 | ponnani
# Processing Record 42 of Set 7 | zaysan
# Processing Record 43 of Set 7 | yangambi
# Processing Record 44 of Set 7 | mumford
# Processing Record 45 of Set 7 | porto seguro
# Processing Record 46 of Set 7 | dudinka
# Processing Record 47 of Set 7 | binga
# Processing Record 48 of Set 7 | bom jesus
# Processing Record 49 of Set 7 | baft
# Processing Record 50 of Set 7 | coulihaut
# City not found. Skipping...
# Processing Record 1 of Set 8 | kodarma
# Processing Record 2 of Set 8 | senador jose porfirio
# Processing Record 3 of Set 8 | nyanguge
# Processing Record 4 of Set 8 | san juan
# Processing Record 5 of Set 8 | marrakesh
# Processing Record 6 of Set 8 | honningsvag
# Processing Record 7 of Set 8 | port-cartier
# Processing Record 8 of Set 8 | calvia
# Processing Record 9 of Set 8 | ballina
# Processing Record 10 of Set 8 | porto velho
# Processing Record 11 of Set 8 | bubanza
# Processing Record 12 of Set 8 | chancay
# Processing Record 13 of Set 8 | sao miguel do araguaia
# Processing Record 14 of Set 8 | shakiso
# Processing Record 15 of Set 8 | bassar
# Processing Record 16 of Set 8 | maloyaz
# City not found. Skipping...
# Processing Record 17 of Set 8 | killybegs
# Processing Record 18 of Set 8 | oussouye
# Processing Record 19 of Set 8 | naryan-mar
# Processing Record 20 of Set 8 | menongue
# Processing Record 21 of Set 8 | timizart
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | thohoyandou
# Processing Record 24 of Set 8 | kasongo-lunda
# Processing Record 25 of Set 8 | warri
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | burica
# City not found. Skipping...
# Processing Record 28 of Set 8 | euclides da cunha
# Processing Record 29 of Set 8 | konya
# Processing Record 30 of Set 8 | arlit
# Processing Record 31 of Set 8 | chambersburg
# Processing Record 32 of Set 8 | charagua
# Processing Record 33 of Set 8 | pavilosta
# Processing Record 34 of Set 8 | stralsund
# Processing Record 35 of Set 8 | verkhniy baskunchak
# Processing Record 36 of Set 8 | yuzhnyy
# Processing Record 37 of Set 8 | ambilobe
# Processing Record 38 of Set 8 | pudozh
# Processing Record 39 of Set 8 | ashqelon
# Processing Record 40 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 8 | sesheke
# Processing Record 42 of Set 8 | merke
# Processing Record 43 of Set 8 | kuytun
# Processing Record 44 of Set 8 | shu
# Processing Record 45 of Set 8 | moose factory
# Processing Record 46 of Set 8 | narasimharajapura
# Processing Record 47 of Set 8 | bengkulu
# Processing Record 48 of Set 8 | sudak
# Processing Record 49 of Set 8 | remedios
# Processing Record 50 of Set 8 | manacapuru
# Processing Record 1 of Set 9 | tabuk
# Processing Record 2 of Set 9 | panambi
# Processing Record 3 of Set 9 | patos
# Processing Record 4 of Set 9 | misratah
# Processing Record 5 of Set 9 | tukrah
# Processing Record 6 of Set 9 | thompson
# Processing Record 7 of Set 9 | vastervik
# City not found. Skipping...
# Processing Record 8 of Set 9 | cumra
# Processing Record 9 of Set 9 | lexington park
# Processing Record 10 of Set 9 | novyy urengoy
# Processing Record 11 of Set 9 | caxito
# Processing Record 12 of Set 9 | teodoro sampaio
# Processing Record 13 of Set 9 | albania
# Processing Record 14 of Set 9 | quatre cocos
# Processing Record 15 of Set 9 | goma
# Processing Record 16 of Set 9 | nouakchott
# Processing Record 17 of Set 9 | saint-paul
# Processing Record 18 of Set 9 | barra do garcas
# Processing Record 19 of Set 9 | ribeira brava
# Processing Record 20 of Set 9 | carmo do rio claro
# Processing Record 21 of Set 9 | port-gentil
# Processing Record 22 of Set 9 | kattivakkam
# Processing Record 23 of Set 9 | eyl
# Processing Record 24 of Set 9 | pangnirtung
# Processing Record 25 of Set 9 | rock sound
# Processing Record 26 of Set 9 | tevriz
# Processing Record 27 of Set 9 | clyde river
# Processing Record 28 of Set 9 | pinheiro machado
# Processing Record 29 of Set 9 | el paso
# Processing Record 30 of Set 9 | duz
# City not found. Skipping...
# Processing Record 31 of Set 9 | campo grande
# Processing Record 32 of Set 9 | yining
# Processing Record 33 of Set 9 | punjai puliyampatti
# Processing Record 34 of Set 9 | quimper
# Processing Record 35 of Set 9 | tocopilla
# Processing Record 36 of Set 9 | axim
# Processing Record 37 of Set 9 | krasnyy yar
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | aksay
# Processing Record 40 of Set 9 | toulepleu
# City not found. Skipping...
# Processing Record 41 of Set 9 | kralendijk
# Processing Record 42 of Set 9 | lekoni
# Processing Record 43 of Set 9 | cap malheureux
# Processing Record 44 of Set 9 | russkaya polyana
# Processing Record 45 of Set 9 | lemesos
# City not found. Skipping...
# Processing Record 46 of Set 9 | korla
# Processing Record 47 of Set 9 | saint-leu
# Processing Record 48 of Set 9 | camargo
# Processing Record 49 of Set 9 | sao gabriel da cachoeira
# Processing Record 50 of Set 9 | venice
# Processing Record 1 of Set 10 | maceio
# Processing Record 2 of Set 10 | buraydah
# Processing Record 3 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 10 | saint anthony
# Processing Record 5 of Set 10 | opole
# Processing Record 6 of Set 10 | grand gaube
# Processing Record 7 of Set 10 | bauchi
# Processing Record 8 of Set 10 | benghazi
# Processing Record 9 of Set 10 | salekhard
# Processing Record 10 of Set 10 | moss point
# Processing Record 11 of Set 10 | juntas
# Processing Record 12 of Set 10 | hobyo
# Processing Record 13 of Set 10 | dhidhdhoo
# Processing Record 14 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 10 | obo
# Processing Record 16 of Set 10 | lincoln
# Processing Record 17 of Set 10 | santa cruz cabralia
# Processing Record 18 of Set 10 | kalengwa
# Processing Record 19 of Set 10 | buyukcavuslu
# Processing Record 20 of Set 10 | laje
# Processing Record 21 of Set 10 | tonstad
# Processing Record 22 of Set 10 | lebu
# Processing Record 23 of Set 10 | aksarka
# Processing Record 24 of Set 10 | bykovo
# Processing Record 25 of Set 10 | marawi
# Processing Record 26 of Set 10 | yertsevo
# Processing Record 27 of Set 10 | westport
# Processing Record 28 of Set 10 | prainha
# Processing Record 29 of Set 10 | shamary
# Processing Record 30 of Set 10 | bembereke
# Processing Record 31 of Set 10 | iisalmi
# Processing Record 32 of Set 10 | mahibadhoo
# Processing Record 33 of Set 10 | maksatikha
# Processing Record 34 of Set 10 | eenhana
# Processing Record 35 of Set 10 | shediac
# Processing Record 36 of Set 10 | kraljevo
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | teguldet
# Processing Record 39 of Set 10 | leh
# Processing Record 40 of Set 10 | illapel
# Processing Record 41 of Set 10 | belmonte
# Processing Record 42 of Set 10 | imbituba
# Processing Record 43 of Set 10 | hadsund
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 10 | siguiri
# Processing Record 47 of Set 10 | ibra
# Processing Record 48 of Set 10 | bulaevo
# Processing Record 49 of Set 10 | marsa matruh
# Processing Record 50 of Set 10 | mpika
# Processing Record 1 of Set 11 | keetmanshoop
# Processing Record 2 of Set 11 | panama city
# Processing Record 3 of Set 11 | kamenka
# Processing Record 4 of Set 11 | boende
# Processing Record 5 of Set 11 | tazovskiy
# Processing Record 6 of Set 11 | maloy
# Processing Record 7 of Set 11 | port blair
# Processing Record 8 of Set 11 | porto de moz
# Processing Record 9 of Set 11 | santa isabel do rio negro
# Processing Record 10 of Set 11 | puerto el triunfo
# Processing Record 11 of Set 11 | carballo
# Processing Record 12 of Set 11 | algiers
# Processing Record 13 of Set 11 | pisco
# Processing Record 14 of Set 11 | oranjestad
# Processing Record 15 of Set 11 | solton
# Processing Record 16 of Set 11 | troyes
# Processing Record 17 of Set 11 | sakakah
# Processing Record 18 of Set 11 | ylojarvi
# Processing Record 19 of Set 11 | lisakovsk
# Processing Record 20 of Set 11 | alta floresta
# Processing Record 21 of Set 11 | hualmay
# Processing Record 22 of Set 11 | tessalit
# Processing Record 23 of Set 11 | dakoro
# Processing Record 24 of Set 11 | birao
# Processing Record 25 of Set 11 | gariaband
# Processing Record 26 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 11 | mana
# Processing Record 28 of Set 11 | marsh harbour
# Processing Record 29 of Set 11 | grand baie
# Processing Record 30 of Set 11 | porbandar
# Processing Record 31 of Set 11 | kaka
# Processing Record 32 of Set 11 | road town
# Processing Record 33 of Set 11 | hopelchen
# Processing Record 34 of Set 11 | bollnas
# Processing Record 35 of Set 11 | nizwa
# Processing Record 36 of Set 11 | high rock
# Processing Record 37 of Set 11 | elmadag
# Processing Record 38 of Set 11 | biltine
# Processing Record 39 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 40 of Set 11 | kudahuvadhoo
# Processing Record 41 of Set 11 | liepaja
# Processing Record 42 of Set 11 | nahavand
# Processing Record 43 of Set 11 | leningradskiy
# Processing Record 44 of Set 11 | mantua
# Processing Record 45 of Set 11 | mufumbwe
# Processing Record 46 of Set 11 | nueve de julio
# Processing Record 47 of Set 11 | ugoofaaru
# Processing Record 48 of Set 11 | aden
# Processing Record 49 of Set 11 | luxor
# Processing Record 50 of Set 11 | senneterre
# Processing Record 1 of Set 12 | muskegon
# Processing Record 2 of Set 12 | krasnofarfornyy
# Processing Record 3 of Set 12 | dingle
# Processing Record 4 of Set 12 | bridlington
# Processing Record 5 of Set 12 | oksovskiy
# Processing Record 6 of Set 12 | maurepas
# Processing Record 7 of Set 12 | urubicha
# Processing Record 8 of Set 12 | madingou
# Processing Record 9 of Set 12 | radhanpur
# Processing Record 10 of Set 12 | cascais
# Processing Record 11 of Set 12 | bara
# Processing Record 12 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 13 of Set 12 | jabinyanah
# Processing Record 14 of Set 12 | sandane
# Processing Record 15 of Set 12 | buta
# Processing Record 16 of Set 12 | katunki
# City not found. Skipping...
# Processing Record 17 of Set 12 | priiskovyy
# Processing Record 18 of Set 12 | itaituba
# Processing Record 19 of Set 12 | hartselle
# Processing Record 20 of Set 12 | biloxi
# Processing Record 21 of Set 12 | acari
# Processing Record 22 of Set 12 | padang
# Processing Record 23 of Set 12 | kargasok
# Processing Record 24 of Set 12 | saint-francois
# Processing Record 25 of Set 12 | ntungamo
# Processing Record 26 of Set 12 | parana
# Processing Record 27 of Set 12 | narodychi
# Processing Record 28 of Set 12 | bagnolo mella
# Processing Record 29 of Set 12 | agaro
# Processing Record 30 of Set 12 | guatire
# Processing Record 31 of Set 12 | campi bisenzio
# Processing Record 32 of Set 12 | pimenta bueno
# Processing Record 33 of Set 12 | kalino
# Processing Record 34 of Set 12 | louga
# Processing Record 35 of Set 12 | barsovo
# Processing Record 36 of Set 12 | atar
# Processing Record 37 of Set 12 | granadilla de abona
# Processing Record 38 of Set 12 | desnogorsk
# Processing Record 39 of Set 12 | bafq
# Processing Record 40 of Set 12 | hirapur
# Processing Record 41 of Set 12 | iracoubo
# Processing Record 42 of Set 12 | rabo de peixe
# Processing Record 43 of Set 12 | santa maria
# Processing Record 44 of Set 12 | sucre
# Processing Record 45 of Set 12 | pandamatenga
# Processing Record 46 of Set 12 | amapa
# Processing Record 47 of Set 12 | araouane
# Processing Record 48 of Set 12 | dawlatabad
# Processing Record 49 of Set 12 | sobreira
# Processing Record 50 of Set 12 | pemba
# Processing Record 1 of Set 13 | lucea
# Processing Record 2 of Set 13 | maun
# Processing Record 3 of Set 13 | diego de almagro
# Processing Record 4 of Set 13 | adre
# Processing Record 5 of Set 13 | thyboron
# Processing Record 6 of Set 13 | boda
# Processing Record 7 of Set 13 | kushmurun
# Processing Record 8 of Set 13 | okahandja
# Processing Record 9 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 10 of Set 13 | blahodatne
# Processing Record 11 of Set 13 | tomar do geru
# Processing Record 12 of Set 13 | itarema
# Processing Record 13 of Set 13 | mogadishu
# Processing Record 14 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 13 | caraballeda
# Processing Record 16 of Set 13 | daugai
# Processing Record 17 of Set 13 | gamba
# Processing Record 18 of Set 13 | mwinilunga
# Processing Record 19 of Set 13 | xuddur
# Processing Record 20 of Set 13 | stokmarknes
# Processing Record 21 of Set 13 | strezhevoy
# Processing Record 22 of Set 13 | muleba
# Processing Record 23 of Set 13 | nurobod
# Processing Record 24 of Set 13 | conceicao do araguaia
# Processing Record 25 of Set 13 | nkhata bay
# Processing Record 26 of Set 13 | langholm
# Processing Record 27 of Set 13 | mirabad
# Processing Record 28 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 29 of Set 13 | mayor pablo lagerenza
# Processing Record 30 of Set 13 | meghri
# Processing Record 31 of Set 13 | ketchenery
# City not found. Skipping...
# Processing Record 32 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 33 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 13 | waddan
# Processing Record 35 of Set 13 | santo antonio do sudoeste
# Processing Record 36 of Set 13 | kisangani
# Processing Record 37 of Set 13 | mao
# Processing Record 38 of Set 13 | sevnica
# Processing Record 39 of Set 13 | sanford
# Processing Record 40 of Set 13 | pimentel
# Processing Record 41 of Set 13 | santa vitoria do palmar
# Processing Record 42 of Set 13 | tabou
# Processing Record 43 of Set 13 | saint-georges
# Processing Record 44 of Set 13 | riyadh
# Processing Record 45 of Set 13 | bejar
# Processing Record 46 of Set 13 | nadym
# Processing Record 47 of Set 13 | riacho de santana
# Processing Record 48 of Set 13 | lindi
# Processing Record 49 of Set 13 | raahe
# Processing Record 50 of Set 13 | karaidel
# Processing Record 1 of Set 14 | jaru
# Processing Record 2 of Set 14 | san andres
# Processing Record 3 of Set 14 | altay
# Processing Record 4 of Set 14 | pangoa
# Processing Record 5 of Set 14 | urumqi
# Processing Record 6 of Set 14 | beziers
# Processing Record 7 of Set 14 | dalvik
# Processing Record 8 of Set 14 | manadhoo
# Processing Record 9 of Set 14 | turukhansk
# Processing Record 10 of Set 14 | villazon
# Processing Record 11 of Set 14 | alexandria
# Processing Record 12 of Set 14 | mufulira
# Processing Record 13 of Set 14 | dekoa
# City not found. Skipping...
# Processing Record 14 of Set 14 | bohuslav
# Processing Record 15 of Set 14 | gerash
# Processing Record 16 of Set 14 | dunmore town
# Processing Record 17 of Set 14 | havre-saint-pierre
# Processing Record 18 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | hit
# Processing Record 20 of Set 14 | sorkjosen
# Processing Record 21 of Set 14 | san luis
# Processing Record 22 of Set 14 | jacareacanga
# Processing Record 23 of Set 14 | lucapa
# Processing Record 24 of Set 14 | kaduqli
# Processing Record 25 of Set 14 | tczew
# Processing Record 26 of Set 14 | geilo
# Processing Record 27 of Set 14 | pizarro
# Processing Record 28 of Set 14 | juli
# Processing Record 29 of Set 14 | lagunas
# Processing Record 30 of Set 14 | abha
# Processing Record 31 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 32 of Set 14 | anloga
# Processing Record 33 of Set 14 | visby
# Processing Record 34 of Set 14 | carupano
# Processing Record 35 of Set 14 | abu samrah
# Processing Record 36 of Set 14 | dourbali
# Processing Record 37 of Set 14 | arusha
# Processing Record 38 of Set 14 | berlin
# Processing Record 39 of Set 14 | thaba-tseka
# Processing Record 40 of Set 14 | jalu
# Processing Record 41 of Set 14 | san javier
# Processing Record 42 of Set 14 | barda
# Processing Record 43 of Set 14 | lamu
# Processing Record 44 of Set 14 | sena madureira
# Processing Record 45 of Set 14 | silvan
# Processing Record 46 of Set 14 | vredendal
# Processing Record 47 of Set 14 | cheremukhovo
# Processing Record 48 of Set 14 | doha
# Processing Record 49 of Set 14 | macamic
# Processing Record 50 of Set 14 | mezdra
# Processing Record 1 of Set 15 | meulaboh
# Processing Record 2 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 15 | nchelenge
# Processing Record 4 of Set 15 | strandby
# Processing Record 5 of Set 15 | constantine
# Processing Record 6 of Set 15 | sajanan
# Processing Record 7 of Set 15 | bad neuenahr-ahrweiler
# Processing Record 8 of Set 15 | kurush
# Processing Record 9 of Set 15 | liwale
# Processing Record 10 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 11 of Set 15 | camocim
# Processing Record 12 of Set 15 | mola di bari
# Processing Record 13 of Set 15 | tamandare
# Processing Record 14 of Set 15 | novoagansk
# Processing Record 15 of Set 15 | clarence town
# Processing Record 16 of Set 15 | newton abbot
# Processing Record 17 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 15 | cuamba
# Processing Record 19 of Set 15 | oranjemund
# Processing Record 20 of Set 15 | aksarayskiy
# Processing Record 21 of Set 15 | manono
# Processing Record 22 of Set 15 | sinop
# Processing Record 23 of Set 15 | olinda
# Processing Record 24 of Set 15 | pamyat parizhskoy kommuny
# Processing Record 25 of Set 15 | olawa
# Processing Record 26 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 15 | monrovia
# Processing Record 28 of Set 15 | edd
# Processing Record 29 of Set 15 | rajauri
# Processing Record 30 of Set 15 | nador
# Processing Record 31 of Set 15 | utraula
# Processing Record 32 of Set 15 | rio claro
# Processing Record 33 of Set 15 | eldorado
# Processing Record 34 of Set 15 | kolpny
# Processing Record 35 of Set 15 | zharkent
# Processing Record 36 of Set 15 | valley
# Processing Record 37 of Set 15 | wisconsin rapids
# Processing Record 38 of Set 15 | tabas
# Processing Record 39 of Set 15 | taoudenni
# Processing Record 40 of Set 15 | gazanjyk
# Processing Record 41 of Set 15 | minas
# Processing Record 42 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 15 | hollins
# Processing Record 44 of Set 15 | praia da vitoria
# Processing Record 45 of Set 15 | mazagao
# Processing Record 46 of Set 15 | zaranj
# Processing Record 47 of Set 15 | mocuba
# Processing Record 48 of Set 15 | tuzha
# Processing Record 49 of Set 15 | palmas bellas
# Processing Record 50 of Set 15 | marv dasht
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Constitucion      CL -35.3333 -72.4167     61.45        69          93
# 1     Punta Arenas      CL -53.1500 -70.9167     50.00        57          40
# 2          Lusambo      CD  -4.9667  23.4500     91.24        46          64
# 3     Ponta Do Sol      PT  32.6667 -17.1000     68.00        60          20
# 4       Nouadhibou      MR  20.9310 -17.0347     78.80        50           0
# ..             ...     ...      ...      ...       ...       ...         ...
# 688        Mazagao      BR  -0.1150 -51.2894     87.80        66          75
# 689         Zaranj      AF  30.9667  61.8833     66.20        24           0
# 690         Mocuba      MZ -16.8392  36.9856     80.26        81          17
# 691          Tuzha      RU  57.6062  47.9360     31.82        86         100
# 692  Palmas Bellas      PA   9.2319 -80.0867     88.00        59           0
#
#      Wind Speed Current Description
# 0          7.74     overcast clouds
# 1         35.68    scattered clouds
# 2          2.77       broken clouds
# 3         14.97          few clouds
# 4         12.66           clear sky
# ..          ...                 ...
# 688        5.75       broken clouds
# 689        6.91           clear sky
# 690        3.76          few clouds
# 691       14.41                snow
# 692       11.01           clear sky
#
# [693 rows x 9 columns]
